# %%
import pandas as pd

# %%
model_scores = pd.read_csv('../data/model_scores.csv', index_col=0)
model_scores = model_scores[['model', 'train_accuracy', 'test_accuracy', 'train_precision', 'test_precision', 'train_recall', 
                             'test_recall', 'train_f1', 'test_f1']]
model_scores.set_index('model')
# Out:
#                      train_accuracy  test_accuracy  train_precision  \
# model
# Dummy Classifier               50.0           98.0              0.0
# Logistic Regression            61.6           44.1             58.6
# Naive Bayes                    53.2           10.3             51.7
# Decision Trees                100.0           96.0            100.0
# Bagged Trees                  100.0           96.3            100.0
# Random Forest                  69.3           81.7             76.8
# AdaBoost                      100.0           96.5            100.0
# Gradient Boosting             100.0           96.3            100.0
# XGBoost                        96.1           97.8             99.8
# SVM                            96.3           93.6             95.7
# KNN                            97.4           90.5             95.1
#
#                      test_precision  train_recall  test_recall  train_f1  \
# model
# ...

# %%
model_scores.sort_values(by=('test_recall'), ascending=False)
# Out:
#                   model  train_accuracy  test_accuracy  train_precision  \
# 2           Naive Bayes            53.2           10.3             51.7
# 1   Logistic Regression            61.6           44.1             58.6
# 5         Random Forest            69.3           81.7             76.8
# 10                  KNN            97.4           90.5             95.1
# 9                   SVM            96.3           93.6             95.7
# 3        Decision Trees           100.0           96.0            100.0
# 7     Gradient Boosting           100.0           96.3            100.0
# 4          Bagged Trees           100.0           96.3            100.0
# 6              AdaBoost           100.0           96.5            100.0
# 0      Dummy Classifier            50.0           98.0              0.0
# 8               XGBoost            96.1           97.8             99.8
#
#     test_precision  train_recall  test_recall  train_f1  test_f1
# ...
